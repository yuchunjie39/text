# %% [markdown]
# # 数学函数、字符串和对象
# ## 本章介绍Python函数来执行常见的数学运算
# - 函数是完成一个特殊任务的一组语句，可以理解为一个函数相当于一个小功能，但是在开发中，需要注意一个函数的长度最好不要超过一屏
# - Python中的内置函数是不需要Import导入的
# <img src="../Photo/15.png"></img>

# %%
abs(-20) #绝对值
max(1,9,20,93)  #最大值
max('a','b','A')
max('abcA')
pow(x,y,z) #x**y模z
# Out:
# 0

# %%
if condition:
    max
elif condition:
    min
elif condition:    
    pow +

# %%
a,b,c = eval(input ('输入三个数：'))
method = input ('请选择执行方式max、min、pow：')
if method == 'max' :
    max_ = max(a,b,c)
    print (max_)
elif method == 'min':
     min_ = min(a,b,c)
     print (min_)
elif method == 'pow':
    pow_sum = pow(a,2)+pow(b,2)+pow(c,2)
    print(pow_sum)
# Out:
# 输入三个数：1,2,3
# 请选择执行方式max、min、pow：pow
# 14

# %% [markdown]
# ## 尝试练习Python内置函数

# %% [markdown]
# ## Python中的math模块提供了许多数学函数
# <img src="../Photo/16.png"></img>
# <img src="../Photo/17.png"></img>

# %%
import math
# math.fabs(-9)
math.ceil(1.1)
# Out:
# 2

# %%
import math
import matplotlib.pyplot as plt
list_ = []
for z in range(-50,50):
    res=1./ (1.+ math.exp(-z))
    list_.append(res)
plt.plot(list_)
plt.show()

# %%
import random
random_num = random.random()/10000
res=1./ (1.+ math.exp(-random_num))
res
# round(1.75)
# Out:
# 0.5000248703779004

# %%
import math
import matplotlib.pyplot as plt
image = plt.imread('/Users/LENOVO/Pictures/6.jpg')
plt.imshow(image)  #plt.imshow(image/math.sin(90))

# %% [markdown]
# ## 两个数学常量PI和e，可以通过使用math.pi 和math.e调用

# %% [markdown]
# ## EP:
# - 通过math库，写一个程序，使得用户输入三个顶点(x,y)返回三个角度
# - 注意：Python计算角度为弧度制，需要将其转换为角度
# <img src="../Photo/18.png">

# %%
import math
x1,y1,x2,y2,x3,y3 = eval(input(''))
a = math.sqrt((x2-x3)**2 + (y2-y3)**2)
b = math.sqrt((x1-x3)**2 + (y1-y3)**2)
c = math.sqrt((x1-x2)**2 + (y1-y2)**2)
A = math.acos((a*a - b*b - c*c) / (-2 * b * c))
B = math.acos((b*b - a*a - c*c) / (-2 * a * c))
C = math.acos((c*c - b*b - c*c) / (-2 * a * b))
print(math.degrees(A),math.degrees(B),math.degrees(C))
# Out:
# 0,0,0,1,1,0
# 90.00000000000001 44.999999999999986 69.29518894536457

# %% [markdown]
# ## 字符串和字符
# - 在Python中，字符串必须是在单引号或者双引号内，在多段换行的字符串中可以使用“”“
# - 在使用”“”时，给予其变量则变为字符串，否则当多行注释使用

# %%
a = """jsksjckhsdh
dlfskdsfld"""  #"""  三个引号可以换行放一个人内，多行注释"""

# %% [markdown]
# ## ASCII码与Unicode码
# - <img src="../Photo/19.png"></img>
# - <img src="../Photo/20.png"></img>
# - <img src="../Photo/21.png"></img>

# %% [markdown]
# ## 函数ord、chr
# - ord 返回ASCII码值
# - chr 返回字符

# %%
ord('与') #接收十进制
# Out:
# 19982

# %%
chr(102)
# Out:
# 'f'

# %%
title = 'y c j'
for i in title:
    print(chr(ord(i)+10))
# Out:
# 
# *
# m
# *
# t

# %% [markdown]
# ## EP:
# - 利用ord与chr进行简单邮箱加密

# %%
title = '1452193446@qq.com'
for i in title:
    print(chr(ord(i)+10),end='')#end=''只适用于输出
# Out:
# ;>?<;C=>>@J{{8myw

# %%
title = '1452193446@qq.com'
result = ''
for i in title:
    result = result + chr(ord(i)+10)
print(result)
# Out:
# ;>?<;C=>>@J{{8myw

# %%
import hashlib
str_ = 'hello'
h1 = hashlib.md5()
h1.update(str_.encode(encoding = 'utf-8'))
print('MD5加密前：'+ str_)
print('MD5加密后：'+ h1.hexdigest())
# Out:
# MD5加密前：hello
# MD5加密后：5d41402abc4b2a76b9719d911017c592

# %%
import hashlib
str_ = '5d41402abc4b2a76b9719d911017c592'
password = input('请输入密码：')
h1 = hashlib.md5()
h1.update(str_.encode(encoding = 'utf-8'))
if str_ == h1.hexdigest():
    print('success')
else:
    print('faild')
# Out:
# 请输入密码：hello
# faild

# %% [markdown]
# ## 转义序列 \
# - a = "He said,"Johon's program is easy to read"
# - 转掉它原来的意思
# - 一般情况下只有当语句与默认方法相撞的时候，就需要转义

# %%
a = "He said,\"Johon's program is easy to read"

# %% [markdown]
# ## 高级print
# - 参数 end： 以什么方式结束打印
# - 默认换行打印

# %%
print('a','b',sep='',end='!',flush=True)
# Out:
# ab!

# %% [markdown]
# ## 函数str
# - 将类型强制转换成字符串类型
# - 其他一些以后会学到(list,set,tuple...)

# %%
str(('1','2','3'))
# Out:
# "('1', '2', '3')"

# %% [markdown]
# ## 字符串连接操作
# - 直接使用 “+”
# - join() 函数

# %%
'a'+'b'
# Out:
# 'ab'

# %%
'!'.join('abcd')
'!'.join(['1','2','3'])
# %time '!'.join(['1','2','3'])
# Out:
# Wall time: 0 ns
# '1!2!3'

# %%
for i in range (1,101):
    url = ''.join(['http://www.../?page= ',str(i) ])
    print(url)

# %% [markdown]
# ## EP：
# - 将 “Welcome” “to” "Python" 拼接
# - 将int型 100 与 “joker is a bad man” 拼接
# - 从控制台读取字符串
# > 输入一个名字返回夸奖此人

# %%
' '.join(['welcome','to','python'])
# Out:
# 'welcome to python'

# %%
'joker is a bad man ' + str(100)
# Out:
# 'joker is a bad man 100'

# %%
name = input('')
print(name,'你真',sep='')
# Out:
# ee
# ee你真

# %% [markdown]
# ## 实例研究：最小数量硬币
# - 开发一个程序，让用户输入总金额，这是一个用美元和美分表示的浮点值，返回一个由美元、两角五分的硬币、一角的硬币、五分硬币、以及美分个数
# <img src="../Photo/22.png"></img>

# %% [markdown]
# - Python弱项，对于浮点型的处理并不是很好，但是处理数据的时候使用的是Numpy类型
# <img src="../Photo/23.png"></img>

# %%
num = 10
while num != 0:
    num -=0.1
    print(num)

# %% [markdown]
# ## id与type
# - id 查看内存地址，在判断语句中将会使用
# - type 查看元素类型

# %%
type(0.0)
# Out:
# float

# %%
a=257 #257之前一样，之后不一样
b=257
print(id(a),id(b))
# Out:
# 661590942224 661590942576

# %% [markdown]
# ## 其他格式化语句见书

# %% [markdown]
# # Homework
# - 1
# <img src="../Photo/24.png"><img>
# <img src="../Photo/25.png"><img>

# %%
import math
r = eval (input('请输入顶点到中心的距离：'))
s = 2 * r * math.sin(math.pi / 5)
area = 5 * s ** 2 / (4*math.tan(math.pi/5))
print('五边形面积为：'+str(round(area,2)))
# Out:
# 请输入顶点到中心的距离：5.5
# 五边形面积为：71.92

# %% [markdown]
# - 2
# <img src="../Photo/26.png"><img>

# %%
import math
x1,y1 = eval(input('Enter point 1(latitude and longitude) in degrees:'))
x2,y2 = eval(input('Enter point 2(latitude and longitude) in degrees:'))
m = math.radians(x1)
n = math.radians(x2)
t = math.radians(y1-y2)
d = 6371.01 * math.acos(math.sin(m)*math.sin(n) + math.cos(m)*math.cos(n) * math.cos(t))
print('The distance between the two points is '+str(d)+' km')
# Out:
# Enter point 1(latitude and longitude) in degrees:39.55,-116.25
# Enter point 2(latitude and longitude) in degrees:41.5,87.37
# The distance between the two points is 10691.79183231593 km

# %% [markdown]
# - 3
# <img src="../Photo/27.png"><img>

# %%
import math
s = eval (input('请输入五角星边长：'))
area = 5 * s ** 2 / (4 * math.tan(math.pi / 5))
print('五角星的面积为：'+str(round(area,2)))
# Out:
# 请输入五角星边长：5.5
# 五角星的面积为：52.04

# %% [markdown]
# - 4
# <img src="../Photo/28.png"><img>

# %%
import math
n = eval (input('请输入多边形边个数：'))
s = eval (input('请输入多边形边长：'))
area = n * s ** 2 / (4 * math.tan(math.pi / n))
print('The area of the polygon is '+ str(area))
# Out:
# 请输入多边形边个数：5
# 请输入多边形边长：6.5
# The area of the polygon is 72.69017017488386

# %% [markdown]
# - 5
# <img src="../Photo/29.png"><img>
# <img src="../Photo/30.png"><img>

# %%
num = eval (input('请输入一个0到127之间的数:'))
print('The character is '+chr(num))
# Out:
# 请输入一个0到127之间的数:69
# The character is E

# %% [markdown]
# - 6
# <img src="../Photo/31.png"><img>

# %%
name = input('雇员姓名:')
hours = eval(input('一周工作时间:'))
rate = eval(input('每小时报酬:'))
federal = eval(input('联邦预扣税率:'))
state = eval(input('州扣税率:'))
cross = hours * rate
fw = hours * rate * 0.2
sw = hours * rate * 0.09
td = hours * rate * 0.2 + hours * rate * 0.09
np=cross - td
print ('Employee name:'+ str(name))
print ('Hours worked:'+ str(hours))
print ('Pay rate: $'+ str(rate))
print ('Cross pay: $'+ str(cross))
print ('Deductions:')
print ('  Federal withholding(20.0%):'+ str(fw))
print ('  State withholding(9.0%):'+ str(sw))
print ('  Total Deduction:'+ str(td))
print ('Net pay: $'+ str(np))
# Out:
# 雇员姓名:Smith
# 一周工作时间:10
# 每小时报酬:9.75
# 联邦预扣税率:0.2
# 州扣税率:0.09
# Employee name:Smith
# Hours worked:10
# Pay rate: $9.75
# Cross pay: $97.5
# Deductions:
#   Federal withholding(20.0%):19.5
#   State withholding(9.0%):8.775
#   Total Deduction:28.275
# Net pay: $69.225

# %% [markdown]
# - 7
# <img src="../Photo/32.png"><img>

# %%
num = eval(input('输入一个四位数：'))
a = num % 10
b = num //10 % 10
c = num //100 % 10
d = num //1000
print(str(a)+str(b)+str(c)+str(d))
# "".join('a','b','c','d')
# Out:
# 输入一个四位数：3125
# 5213

# %% [markdown]
# - 8 进阶：
# > 加密一串文本，并将解密后的文件写入本地保存

# %%
import hashlib
str_ =  input('请输入文本：')
h1 = hashlib.md5()
h1.update(str_.encode(encoding='utf-8'))
file = h1.hexdigest()
file_handle=open('../2.txt',mode='w')
file_handle.write(file)
file_handle.close()
print('存入成功')
# Out:
# 请输入文本：hello
# 存入成功
